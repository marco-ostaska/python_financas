# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader as pdr
import yfinance as yf

# %%
portifolio = yf.download(["HSMAL11.SA", "VGIA11.SA", "HSAF11.SA", "IFRA11.SA"], start="2011-01-01")['Adj Close'].dropna()

portifolio.head()
# Out:
# [*********************100%***********************]  3 of 3 completed
#             HSAF11.SA  IFRA11.SA  VGIA11.SA
# Date
# 2021-12-15  87.427132  95.719200   9.565536
# 2021-12-16  86.114632  95.424850   8.632312
# 2021-12-17  86.086304  95.111511   9.332231
# 2021-12-20  85.142067  95.158997   9.210912
# 2021-12-21  85.925781  96.849106   9.285569

# %%
(portifolio / portifolio.iloc[0] *100).plot(figsize=(8,5))
# Out:
# <Axes: xlabel='Date'>
