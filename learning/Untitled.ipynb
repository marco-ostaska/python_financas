# %%
import pandas as pd
import yfinance as yf
from pypfopt.efficient_frontier import EfficientFrontier
from pypfopt import risk_models
from pypfopt import expected_returns

# %%
df = yf.download(["IBM"]).dropna()
df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1962-01-02    7.374124    7.374124    7.291268    7.291268    1.573411
# 1962-01-03    7.291268    7.355003    7.291268    7.355003    1.587165
# 1962-01-04    7.355003    7.355003    7.278521    7.281708    1.571346
# 1962-01-05    7.272148    7.272148    7.125558    7.138305    1.540402
# 1962-01-08    7.131931    7.131931    6.947100    7.004461    1.511519
# ...                ...         ...         ...         ...         ...
# 2023-09-29  142.000000  142.130005  139.610001  140.300003  140.300003
# 2023-10-02  140.039993  141.449997  139.860001  140.800003  140.800003
# 2023-10-03  140.869995  141.639999  140.000000  140.389999  140.389999
# 2023-10-04  140.369995  141.199997  139.990005  141.070007  141.070007
# 2023-10-05  140.899994  141.639999  140.210007  141.419998  141.419998
#
#              Volume
# Date
# 1962-01-02   407940
# 1962-01-03   305955
# 1962-01-04   274575
# 1962-01-05   384405
# 1962-01-08   572685
# ...             ...
# 2023-09-29  5703600
# 2023-10-02  3275300
# 2023-10-03  3284400
# 2023-10-04  2637600
# 2023-10-05  1375470
#
# [15547 rows x 6 columns]

# %%
mu = expected_returns.mean_historical_return(df)
S = risk_models.sample_cov(df)

# Optimize for maximal Sharpe ratio
ef = EfficientFrontier(mu, S)
weights = ef.max_sharpe()
ef.portfolio_performance(verbose=True)
# Out:
# C:\ProgramData\anaconda3\envs\Financas\Lib\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\ProgramData\anaconda3\envs\Financas\Lib\site-packages\pypfopt\risk_models.py:68: UserWarning: The covariance matrix is non positive semidefinite. Amending eigenvalues.
#   warnings.warn(
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[25], line 2
#       1 mu = expected_returns.mean_historical_return(df)
# ----> 2 S = risk_models.sample_cov(df)
#       4 # Optimize for maximal Sharpe ratio
#       5 ef = EfficientFrontier(mu, S)
#
# File C:\ProgramData\anaconda3\envs\Financas\Lib\site-packages\pypfopt\risk_models.py:171, in sample_cov(prices, returns_data, frequency, log_returns, **kwargs)
#     169 else:
#     170     returns = returns_from_prices(prices, log_returns)
# --> 171 return fix_nonpositive_semidefinite(
#     172     returns.cov() * frequency, kwargs.get("fix_method", "spectral")
#     173 )
#
# File C:\ProgramData\anaconda3\envs\Financas\Lib\site-packages\pypfopt\risk_models.py:73, in fix_nonpositive_semidefinite(matrix, fix_method)
#      68 warnings.warn(
#      69     "The covariance matrix is non positive semidefinite. Amending eigenvalues."
#      70 )
#      72 # Eigendecomposition
# ---> 73 q, V = np.linalg.eigh(matrix)
#      75 if fix_method == "spectral":
#      76     # Remove negative eigenvalues
#      77     q = np.where(q > 0, q, 0)
#
# File C:\ProgramData\anaconda3\envs\Financas\Lib\site-packages\numpy\linalg\linalg.py:1487, in eigh(a, UPLO)
#    1484     gufunc = _umath_linalg.eigh_up
#    1486 signature = 'D->dD' if isComplexType(t) else 'd->dd'
# -> 1487 w, vt = gufunc(a, signature=signature, extobj=extobj)
#    1488 w = w.astype(_realType(result_t), copy=False)
#    1489 vt = vt.astype(result_t, copy=False)
#
# File C:\ProgramData\anaconda3\envs\Financas\Lib\site-packages\numpy\linalg\linalg.py:118, in _raise_linalgerror_eigenvalues_nonconvergence(err, flag)
#     117 def _raise_linalgerror_eigenvalues_nonconvergence(err, flag):
# --> 118     raise LinAlgError("Eigenvalues did not converge")
#
# LinAlgError: Eigenvalues did not converge

# %%
# Calculate expected returns and sample covariance
mu = expected_returns.mean_historical_return(df)
S = risk_models.sample_cov(df)

# Optimize for maximal Sharpe ratio
ef = EfficientFrontier(mu, S)
weights = ef.max_sharpe()
ef.portfolio_performance(verbose=True)
# Out:
# C:\ProgramData\anaconda3\envs\Financas\Lib\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\ProgramData\anaconda3\envs\Financas\Lib\site-packages\pypfopt\risk_models.py:68: UserWarning: The covariance matrix is non positive semidefinite. Amending eigenvalues.
#   warnings.warn(
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[7], line 3
#       1 # Calculate expected returns and sample covariance
#       2 mu = expected_returns.mean_historical_return(df)
# ----> 3 S = risk_models.sample_cov(df)
#       5 # Optimize for maximal Sharpe ratio
#       6 ef = EfficientFrontier(mu, S)
#
# File C:\ProgramData\anaconda3\envs\Financas\Lib\site-packages\pypfopt\risk_models.py:171, in sample_cov(prices, returns_data, frequency, log_returns, **kwargs)
#     169 else:
#     170     returns = returns_from_prices(prices, log_returns)
# --> 171 return fix_nonpositive_semidefinite(
#     172     returns.cov() * frequency, kwargs.get("fix_method", "spectral")
#     173 )
#
# File C:\ProgramData\anaconda3\envs\Financas\Lib\site-packages\pypfopt\risk_models.py:73, in fix_nonpositive_semidefinite(matrix, fix_method)
#      68 warnings.warn(
#      69     "The covariance matrix is non positive semidefinite. Amending eigenvalues."
#      70 )
#      72 # Eigendecomposition
# ---> 73 q, V = np.linalg.eigh(matrix)
#      75 if fix_method == "spectral":
#      76     # Remove negative eigenvalues
#      77     q = np.where(q > 0, q, 0)
#
# File C:\ProgramData\anaconda3\envs\Financas\Lib\site-packages\numpy\linalg\linalg.py:1487, in eigh(a, UPLO)
#    1484     gufunc = _umath_linalg.eigh_up
#    1486 signature = 'D->dD' if isComplexType(t) else 'd->dd'
# -> 1487 w, vt = gufunc(a, signature=signature, extobj=extobj)
#    1488 w = w.astype(_realType(result_t), copy=False)
#    1489 vt = vt.astype(result_t, copy=False)
#
# File C:\ProgramData\anaconda3\envs\Financas\Lib\site-packages\numpy\linalg\linalg.py:118, in _raise_linalgerror_eigenvalues_nonconvergence(err, flag)
#     117 def _raise_linalgerror_eigenvalues_nonconvergence(err, flag):
# --> 118     raise LinAlgError("Eigenvalues did not converge")
#
# LinAlgError: Eigenvalues did not converge
